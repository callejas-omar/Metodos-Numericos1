# %% [markdown]
# <a href="https://colab.research.google.com/github/callejas-omar/Metodos-Numericos1/blob/main/Ejemplo%208%20Nov.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
F=np.array([-5, 1, 9, 25, 55, 105])
x=([0, 1, 2, 3, 4, 5])

# %%
F
# Out:
# array([ -5,   1,   9,  25,  55, 105])

# %%
type(F)
# Out:
# numpy.ndarray

# %%
plt.scatter(x,F, color="Blue", marker='x')
plt.title ("Gráfica de los datos")
plt.xlabel ("Eje x")
plt.ylabel ("Eje y")
plt.grid (color="black", linestyle='--')
plt.show()

# %%
def f(x):
   return -5+7*x-2*x**2+x**3

# %%
x1=np.linspace(0,5,100)

# %%
plt.plot(x1,f(x1))
plt.scatter(x,F, color="orange", marker='x')
plt.xlabel ("Eje x")
plt.ylabel ("Eje y")
plt.grid (color="black", linestyle='--')
plt.show()

# %%
dif= F[1] - F[0]
print(dif)
# Out:
# 6

# %%
delta1=np.array([])
for i in range(len(F)-1):
   dif= F[i+1] - F[i]
   print(dif)
   delta1=np.append(delta1,dif)
   print(delta1)
#Primeras Diferencias
# Out:
# 6
# [6.]
# 8
# [6. 8.]
# 16
# [ 6.  8. 16.]
# 30
# [ 6.  8. 16. 30.]
# 50
# [ 6.  8. 16. 30. 50.]

# %%
#Segundas Diferencias
delta2=np.array([])
for i in range(len(delta1)-1):
   dif= delta1[i+1] - delta1[i]
   print(dif)
   delta2=np.append(delta2,dif)
   print(delta2)
# Out:
# 2.0
# [2.]
# 8.0
# [2. 8.]
# 14.0
# [ 2.  8. 14.]
# 20.0
# [ 2.  8. 14. 20.]

# %%
#Terceras Diferencias
delta3=np.array([])
for i in range(len(delta2)-1):
   dif= delta2[i+1] - delta2[i]
   print(dif)
   delta3=np.append(delta3,dif)
   print(delta3)
# Out:
# 6.0
# [6.]
# 6.0
# [6. 6.]
# 6.0
# [6. 6. 6.]
